# %%
# Import libraries

import nibabel as nii
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ### Comprimento de Onda

# %%
# Resultados extraídos

comp_de_onda = [660, 830, 904]

area_sub = [5.30,7.26,8.48]
area_sub_er = [0.06,0.12,0.18]

raio_saida = [1.299,1.520,1.643]
raio_saida_er = [0.007,0.013,0.017]

fluencia_med = [0.1520,0.1573,0.1526]
fluencia_med_er = [0.0005,0.0010,0.0013]

# %%
# Area sub x lambda
fig,axs = plt.subplots(1, figsize = (10, 7))
sns.set_theme()

plt.errorbar(comp_de_onda, area_sub, yerr=area_sub_er, label='Raio de entrada 1mm', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)
plt.ylabel('Área Subcutânea [mm²]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('grafico1-areasub-comp-onda.jpg',dpi=200)
plt.show()

# %%
# raio saida x lambda
fig,axs = plt.subplots(1, figsize = (10, 7))
sns.set_theme()

plt.errorbar(comp_de_onda, raio_saida, yerr=raio_saida_er, label='Raio de entrada 1mm', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)
plt.ylabel('Raio de saída [mm]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('grafico2-raio-saida-comp-onda.jpg',dpi=200)
plt.show()

# %%
# Area sub x lambda
fig,axs = plt.subplots(1, figsize = (10, 7))
sns.set_theme()

plt.errorbar(comp_de_onda, fluencia_med, yerr=fluencia_med_er, label='Raio de entrada 1mm', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)
plt.ylabel('Fluência Média [J/cm²]', fontsize=15)
plt.grid(alpha=0.3)
plt.ylim(0.140,0.170)


plt.legend()
plt.savefig('grafico3-fluencia-med-comp-onda.jpg',dpi=200)
plt.show()

# %% [markdown]
# ## Divergências

# %%
# Resultados extraídos

diverg = [0.011,0.015,0.020,0.027,0.034]
diverg_er =[0.001,0.001,0.000,0.000,0.008]

area_sub = [30.27,30.27,30.38,30.43,30.52]
area_sub_er = [0.09,0.09,0.07,0.10,0.07]

raio_saida = [3.10,3.10,3.11,3.11,3.12]
raio_saida_er = [0.17,0.17,0.15,0.18,0.15]

fluencia_med = [0.00600,0.00599,0.00598,0.00597,0.00595]
fluencia_med_er = [0.00001,0.00001,0.00001,0.00001,0.00001]

# %%
# Area sub x lambda
fig,axs = plt.subplots(1, figsize = (10, 7))
sns.set_theme()

plt.errorbar(diverg , area_sub, xerr=diverg_er, yerr=area_sub_er, label='Raio de entrada 1mm', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Divergência [rad]', fontsize=15)
plt.ylabel('Área Subcutânea [mm²]', fontsize=15)
plt.grid(alpha=0.3)
plt.ylim(29.8,31)

plt.legend()
plt.savefig('grafico1-areasub-divergencia.jpg',dpi=200)
plt.show()

# %% [markdown]
# ## Raios

# %%
# Resultados extraídos

raios = [0.91,1.41,2.08,2.69,3.46]
raios_er =[0.20,0.54,0.02,0.08,0.38]

area_sub = [7.99,20.93,43.39,67.58,98.04]
area_sub_er = [0.03,0.07,0.06,0.14,0.19]

raio_saida = [1.59,2.58,3.72,4.64,5.59]
raio_saida_er = [0.10,0.15,0.14,0.21,0.25]

fluencia_med = [3.84,5.22,7.08,8.69,11.43]
fluencia_med_er = [0.01,0.01,0.01,0.01,0.01]

# %%
# raio saida x lambda
fig,axs = plt.subplots(1, figsize = (10, 7))
sns.set_theme()

plt.errorbar(raios, raio_saida, xerr=raios_er, yerr=raio_saida_er, label='Raio de entrada 1mm', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Raio da Fonte [mm]', fontsize=15)
plt.ylabel('Raio de saída [mm]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('grafico2-raio-saida-raio-fonte.jpg',dpi=200)
plt.show()

# %%
# Dados simulados para 904 nm

raios_t = [0.5,1.0,2.0] # raios teóricos
areasub_t = [1.74,9.94,40.38] # áreas calculadas 
areasub_ter = [0.03,0.15,1.11] # erro desvpad

raios_r = [1.59, 2.08, 3.46] # raios reais
raios_rer = [0.13,0.43,0.38]
areasub_r = [26.02, 43.8, 70.71] # áreas calculadas
areasub_rer = [0.41,1.4,0.18]

# %%
# Gráfico Áreas subcutâneas em função do raio de entrada


fig,axs = plt.subplots(1, figsize = (10, 7))
plt.errorbar(raios_t, areasub_t, yerr=areasub_ter, label='Raios Teóricos', markerfacecolor='royalblue',fmt='o', ecolor='black',capsize=5)
plt.errorbar(raios_r, areasub_r, xerr=raios_rer, yerr=areasub_rer, label='Raios Reais', markerfacecolor='orangered',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Raio [mm]', fontsize=15)
plt.ylabel('Área Subcutânea [mm²]', fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig('RF_Area_Subcutanea_vs_Raio.jpg',dpi=200)
plt.show()

# %%
# Gráfico Raio Subcutâneo em função do raio de entrada

Yrst = [0.74,1.78,3.59]
Yrster = [0.10,0.03,0.11]
Yrsr = [2.88,3.74,4.74]
Yrsrer = [0.37,0.68,0.24]

fig,axs = plt.subplots(1, figsize = (10, 7))

plt.errorbar(raios_t, Yrst, yerr=Yrster, label='Raios Teóricos', markerfacecolor='royalblue',fmt='o', ecolor='black',capsize=5)
plt.errorbar(raios_r, Yrsr, xerr=raios_rer, yerr=Yrsrer, label='Raios Reais', markerfacecolor='orangered',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.ylabel('Raio de Saída [mm]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('RF_Raio_Saida_vs_Raio_Entrada.jpg',dpi=200)
plt.show()

# %%
# Gráfico de Percentual de atenuação em função do raio de entrada

Ypat = [67.4,40.9,24.1]
Ypater = [0.4,1.0,2.9] 
Ypar = [28.0,23.3,16.2]
Yparer = [1.9,3.5,0.5]

fig,axs = plt.subplots(1, figsize = (10, 7))

plt.errorbar(raios_t, Ypat, yerr=Ypater, label='Raios Teóricos', markerfacecolor='navy',fmt='o', ecolor='black',capsize=5)
plt.errorbar(raios_r, Ypar, xerr=raios_rer, yerr=Yparer, label='Raios Reais', markerfacecolor='firebrick',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.ylabel('Atenuação [%]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('RF_Atenuacao_vs_Raio_Entrada.jpg',dpi=200)
plt.show()

# %% [markdown]
# ### Fontes Girasol

# %%
# Dados

wvlen = [660, 830, 904]

raio = [1.58,2.69,3.46]
raioer = [0.02,0.08,0.38]

areasub = [30.9,52.8,77.6]
areasuber = [0.9,0.1,0.1]

raiosub = [3.14,4.10,4.97]
raiosuber = [0.53,0.22,0.21]

# Percentual de Atenuação do Valor Central
patt = [73.0,35.0,23.0]
patter = [0.7,0.3,0.4]

# Percentual de Atenuação da Fluência Média
fmatt = [72.96,27.64,18.16]
fmatter = [0.30,0.05,0.03]

# %%
# Gráfico Áreas subcutâneas em função do raio de entrada


fig,axs = plt.subplots(1, figsize = (10, 7))

# plt.errorbar(raio, areasub, xerr=raioer, yerr=areasuber, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
plt.errorbar(wvlen, areasub, yerr=areasuber, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
# plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)

plt.ylabel('Área Subcutânea [mm²]', fontsize=15)
plt.grid(alpha=0.3)

plt.savefig('RF_AreaSub_vs_Raio_Entrada_GIRASOL.jpg',dpi=200)
plt.legend()
plt.show()

# %%
# Gráfico raio de saída em função do raio de entrada



fig,axs = plt.subplots(1, figsize = (10, 7))
# plt.errorbar(raio, raiosub, xerr=raioer, yerr=raiosuber, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
plt.errorbar(wvlen, raiosub, yerr=raiosuber, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
# plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)
plt.ylabel('Raio de Saída [mm]', fontsize=15)
plt.grid(alpha=0.3)

plt.savefig('RF_Raio_Saida_vs_Raio_Entrada_GIRASOL.jpg',dpi=200)
plt.legend()
plt.show()

# %%
# Gráfico de percentual de atenuação em função do raio de entrada


fig,axs = plt.subplots(1, figsize = (10, 7))

# plt.errorbar(raio, patt, xerr=raioer, yerr=patter, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
# plt.errorbar(wvlen, patt, yerr=patter, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
plt.errorbar(wvlen, fmatt, yerr=fmatter, label='Fontes Reais', markerfacecolor='limegreen',fmt='o', ecolor='black',capsize=5)
# plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.xlabel('Comprimento de Onda [nm]', fontsize=15)
plt.ylabel('Atenuação [%]', fontsize=15)
plt.grid(alpha=0.3)

plt.savefig('RF_Att_FluenciaMedia_vs_Raio_Entrada_GIRASOL.jpg',dpi=200)
plt.legend()
plt.show()

# %% [markdown]
# ### Fluência Média Subcutânea em função do Raio

# %%
# Dados

raios_t = [0.5,1.0,2.0] # raios teóricos
raios_r = [1.59, 2.08, 3.46] # raios reais
raios_rer = [0.13,0.43,0.38]


fluencia_med_r = [5.84,7.1,9.26]
fluencia_med_rer = [0.05,0.1,0.02]

fluencia_med_t = [2.57,4.17,6.9]
fluencia_med_ter = [0.02,0.03,0.1]

# %%
fig,axs = plt.subplots(1, figsize = (10, 7))

plt.errorbar(raios_t, fluencia_med_t, yerr = fluencia_med_ter, label='Raios Teóricos', markerfacecolor='royalblue',fmt='o', ecolor='black',capsize=5)
plt.errorbar(raios_r, fluencia_med_r, xerr = raios_rer, yerr = fluencia_med_rer, label='Raios Reais', markerfacecolor='orangered',fmt='o', ecolor='black',capsize=5)
plt.xlabel('Raio de Entrada [mm]', fontsize=15)
plt.ylabel('Fluência Média [mJ/cm²]', fontsize=15)
plt.grid(alpha=0.3)

plt.legend()
plt.savefig('RF_FluenciaMed_vs_Raio_Entrada.jpg',dpi=200)
plt.show()
