# %%
# Import libraries

import nibabel as nii
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# # Divergências Teóricas

# %% [markdown]
# ### Aquisição dos Dados

# %%
# 15

image1_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s1.nii')
image2_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s2.nii')
image3_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s3.nii')
image4_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s4.nii')
image5_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s5.nii')

data1_15 = image1_15.get_fdata()
data1_15 = np.squeeze(data1_15)
data2_15 = image2_15.get_fdata()
data2_15 = np.squeeze(data2_15)
data3_15 = image3_15.get_fdata()
data3_15 = np.squeeze(data3_15)
data4_15 = image4_15.get_fdata()
data4_15 = np.squeeze(data4_15)
data5_15 = image5_15.get_fdata()
data5_15 = np.squeeze(data5_15)

# %%
# 60


image1_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s1.nii')
image2_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s2.nii')
image3_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s3.nii')
image4_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s4.nii')
image5_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s5.nii')

data1_60 = image1_60.get_fdata()
data1_60 = np.squeeze(data1_60)
data2_60 = image2_60.get_fdata()
data2_60 = np.squeeze(data2_60)
data3_60 = image3_60.get_fdata()
data3_60 = np.squeeze(data3_60)
data4_60 = image4_60.get_fdata()
data4_60 = np.squeeze(data4_60)
data5_60 = image5_60.get_fdata()
data5_60 = np.squeeze(data5_60)

# %%
# 120

image1_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s1.nii')
image2_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s2.nii')
image3_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s3.nii')
image4_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s4.nii')
image5_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s5.nii')

data1_120 = image1_120.get_fdata()
data1_120 = np.squeeze(data1_120)
data2_120 = image2_120.get_fdata()
data2_120 = np.squeeze(data2_120)
data3_120 = image3_120.get_fdata()
data3_120 = np.squeeze(data3_120)
data4_120 = image4_120.get_fdata()
data4_120 = np.squeeze(data4_120)
data5_120 = image5_120.get_fdata()
data5_120 = np.squeeze(data5_120)

# %% [markdown]
# ### Suavização dos Dados

# %% [markdown]
# 15 graus

# %%
# Criação da Matriz em branco
data_15_s = np.zeros((200,400))

# Loop de suavização do conjunto de dados
for i in range(200):
    for j in range(400):
        data_15_s[i][j]=(data1_15[i][j][200]+data2_15[i][j][200]+data3_15[i][j][200]+data4_15[i][j][200]+data5_15[i][j][200])/5

# %% [markdown]
# 60 graus

# %%
# Criação da Matriz em branco
data_60_s = np.zeros((200,400))

# Loop de suavização do conjunto de dados
for i in range(200):
    for j in range(400):
        data_60_s[i][j]=(data1_60[i][j][200]+data2_60[i][j][200]+data3_60[i][j][200]+data4_60[i][j][200]+data5_60[i][j][200])/5

# %% [markdown]
# 120 graus

# %%
# Criação da Matriz em branco
data_120_s = np.zeros((200,400))

# Loop de suavização do conjunto de dados
for i in range(200):
    for j in range(400):
        data_120_s[i][j]=(data1_120[i][j][200]+data2_120[i][j][200]+data3_120[i][j][200]+data4_120[i][j][200]+data5_120[i][j][200])/5

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(2,0,200)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações - 30mW - 1,0 mm', fontsize=20)

# Actual Lateral View Plot
axs.plot(Y, data_15_s[:,200]*0.0314159265*30, color = 'blue', label = '15°',linewidth=4.0)
axs.plot(Y, data_60_s[:,200]*0.0314159265*30, color = 'red', label = '60°',linewidth=4.0)
axs.plot(Y, data_120_s[:,200]*0.0314159265*30, color = 'green', label = '120°',linewidth=4.0)
plt.legend(loc=1, prop={'size': 25})

# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
# axs.set_ylabel('Fluência Normalizada [$J/cm^2$]', fontsize=30)
axs.set_ylabel('Fluência [mJ/cm²]', fontsize=30)

plt.savefig('grafico7-decaimento-divergencias-teoricas-30mW.jpg', dpi=200)
plt.show()

# %% [markdown]
# ### Fluence Plots

# %%
# Vector to Scale Correction
X = np.linspace(-2,2,400)
Y = np.linspace(-2,0,200)

#Subplot
sns.set_theme()
fig,axs = plt.subplots(3,1, figsize = (12, 10))
plt.suptitle('Fluência Real [mJ/mm²]\nDensidade de Potência Incidente 30mW/mm²', y=0.97, x=0.425, fontsize = 18)
# plt.set_title('$10^8$ fótons - 5 simulações - Densidade de Potência incidente 30mW/mm²', fontsize=15)

plt.subplots_adjust(hspace = 0.5)   # Pushing up the title
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

axs[0].set_title('15°', fontsize=14)
axs[0].contour(X, Y, data_15_s[:,:]*0.0314159265*30, cmap = "jet")
# axs[0].axis('equal')
img0 = axs[0].contour(X, Y, data_15_s[:,:]*0.0314159265*30, cmap = "jet")
fig.colorbar(img0, ax =axs[0])

axs[1].set_title('60°', fontsize=14)
axs[1].contour(X, Y, data_60_s[:,:]*0.0314159265*30, cmap = "jet")
# axs[1].axis('equal')
img1 = axs[1].contour(X, Y, data_60_s[:,:]*0.0314159265*30, cmap = "jet")
fig.colorbar(img1, ax =axs[1])

axs[2].set_title('120°', fontsize=14)
axs[2].contour(X, Y, data_120_s[:,:]*0.0314159265*30, cmap = "jet")
# axs[2].axis('equal')
img2 = axs[2].contour(X, Y, data_120_s[:,:]*0.0314159265*30, cmap = "jet")
fig.colorbar(img2, ax =axs[2])

# Axis config

fig.text(0.45, 0.05, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.05, 0.5, 'Profundidade [mm]', va='center', rotation='vertical', fontsize = 16)

# Saving and plotting
plt.savefig('grafico8-perfil-fluencia-divergencias-teoricas-30mW.jpg', dpi=200)
plt.show()

# %% [markdown]
# # Divergências Girasol

# %% [markdown]
# ### Aquisição de Dados

# %%
# HTM Fluence

image1_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s1.nii')
image2_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s2.nii')
image3_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s3.nii')
image4_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s4.nii')
image5_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s5.nii')

data1_htm = image1_htm.get_fdata()
data1_htm = np.squeeze(data1_htm)
data2_htm = image2_htm.get_fdata()
data2_htm = np.squeeze(data2_htm)
data3_htm = image3_htm.get_fdata()
data3_htm = np.squeeze(data3_htm)
data4_htm = image4_htm.get_fdata()
data4_htm = np.squeeze(data4_htm)
data5_htm = image5_htm.get_fdata()
data5_htm = np.squeeze(data5_htm)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\nibabel\loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [WinError 2] O sistema não pode encontrar o arquivo especificado: 'C:\\Users\\User\\Documents\\Raíssa\\Curso Monte Carlo\\pymcx-master\\pymcx\\F-904-HTM-s1.nii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10064/860309689.py in <module>
#       1 # HTM Fluence
#       2
# ----> 3 image1_htm = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-HTM-s1.nii')
# ...

# %%
# Ibramed 14

image1_ibm14 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED14-s1.nii')
image2_ibm14 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED14-s2.nii')
image3_ibm14 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED14-s3.nii')
image4_ibm14 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED14-s4.nii')
image5_ibm14 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED14-s5.nii')

data1_ibm14 = image1_ibm14.get_fdata()
data1_ibm14 = np.squeeze(data1_ibm14)
data2_ibm14 = image2_ibm14.get_fdata()
data2_ibm14 = np.squeeze(data2_ibm14)
data3_ibm14 = image3_ibm14.get_fdata()
data3_ibm14 = np.squeeze(data3_ibm14)
data4_ibm14 = image4_ibm14.get_fdata()
data4_ibm14 = np.squeeze(data4_ibm14)
data5_ibm14 = image5_ibm14.get_fdata()
data5_ibm14 = np.squeeze(data5_ibm14)

# %%
# Ibramed 11

image1_ibm11 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED11-s1.nii')
image2_ibm11 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED11-s2.nii')
image3_ibm11 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED11-s3.nii')
image4_ibm11 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED11-s4.nii')
image5_ibm11 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-IBRAMED11-s5.nii')

data1_ibm11 = image1_ibm11.get_fdata()
data1_ibm11 = np.squeeze(data1_ibm11)
data2_ibm11 = image2_ibm11.get_fdata()
data2_ibm11 = np.squeeze(data2_ibm11)
data3_ibm11 = image3_ibm11.get_fdata()
data3_ibm11 = np.squeeze(data3_ibm11)
data4_ibm11 = image4_ibm11.get_fdata()
data4_ibm11 = np.squeeze(data4_ibm11)
data5_ibm11 = image5_ibm11.get_fdata()
data5_ibm11 = np.squeeze(data5_ibm11)

# %% [markdown]
# ### Suavização de Dados

# %% [markdown]
# HTM Fluence

# %%
# Criação da Matriz em branco
data_htm_s = np.zeros((300,600))

# Loop de suavização do conjunto de dados
for i in range(300):
    for j in range(600):
        data_htm_s[i][j]=(data1_htm[i][j][300]+data2_htm[i][j][300]+data3_htm[i][j][300]+data4_htm[i][j][300]+data5_htm[i][j][300])/5

# %% [markdown]
# Ibramed 14

# %%
# Criação da Matriz em branco
data_ibm14_s = np.zeros((300,600))

# Loop de suavização do conjunto de dados
for i in range(300):
    for j in range(600):
        data_ibm14_s[i][j]=(data1_ibm14[i][j][300]+data2_ibm14[i][j][300]+data3_ibm14[i][j][300]+data4_ibm14[i][j][300]+data5_ibm14[i][j][300])/5

# %% [markdown]
# Ibramed 11

# %%
# Criação da Matriz em branco
data_ibm11_s = np.zeros((300,600))

# Loop de suavização do conjunto de dados
for i in range(300):
    for j in range(600):
        data_ibm11_s[i][j]=(data1_ibm11[i][j][300]+data2_ibm11[i][j][300]+data3_ibm11[i][j][300]+data4_ibm11[i][j][300]+data5_ibm11[i][j][300])/5

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(1.5,0,150)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações', fontsize=20)

# Actual Lateral View Plot
axs.plot(Y, data_htm_s[150:300,300]*3638281, color = 'blue', label = 'HTM Fluence 0.034 rad - 11,43 mW',linewidth=4.0)
axs.plot(Y, data_ibm14_s[150:300,300]*13324451, color = 'red', label = 'Ibramed 0.043 rad - 41,86 mW',linewidth=4.0)
axs.plot(Y, data_ibm11_s[150:300,300]*15928226, color = 'green', label = 'Ibramed 0.052 rad - 50,04 mW',linewidth=4.0)
plt.legend(loc=1, prop={'size': 25})

# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
axs.set_ylabel('Fluência Real [mJ/mm²]', fontsize=30)

# plt.savefig('POT-REAL-Decaimento-DIV-htm-ibm14-ibm11.jpg', dpi=200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2000/2229631004.py in <module>
# ----> 1 Y = np.linspace(1.5,0,150)
#       2
#       3 sns.set_theme()
#       4 fig,axs = plt.subplots(1, figsize = (20, 14))
#       5 plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Fluence Plots

# %%
# Vector to Scale Correction
X = np.linspace(-0.25,0.25,50)
Y = np.linspace(-0.60,0,60)

#Subplot
sns.set_theme()
fig,axs = plt.subplots(3,1, figsize = (12, 10))
plt.suptitle('Fluência Real [mJ/mm²]\n', y=0.95, x=0.425, fontsize = 18)

plt.subplots_adjust(hspace = 0.5)   # Pushing up the title
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

axs[0].set_title('HTM Fluence 0.034 rad - 11,43 mW/mm²', fontsize=14)
# plt.text(0.1,1.6, '11,43 mW/mm²',fontsize = 16)
axs[0].contour(X, Y, data_htm_s[240:300, 275:325]/278485, cmap = "jet")
# axs[0].axis('equal')
img0 = axs[0].contour(X, Y, data_htm_s[240:300, 275:325]/278485, cmap = "jet")
fig.colorbar(img0, ax =axs[0])

axs[1].set_title('Ibramed 0.043 rad - 41,86 mW/mm²', fontsize=14)
axs[1].contour(X, Y, data_ibm14_s[240:300, 275:325]/76041, cmap = "jet")
# axs[1].axis('equal')
img1 = axs[1].contour(X, Y, data_ibm14_s[240:300, 275:325]/76041, cmap = "jet")
fig.colorbar(img1, ax =axs[1])

axs[2].set_title('Ibramed 0.052 rad - 50,04 mW/mm²', fontsize=14)
axs[2].contour(X, Y, data_ibm11_s[240:300, 275:325]/63610)
# axs[2].axis('equal')
img2 = axs[2].contour(X, Y, data_ibm11_s[240:300, 275:325]/63610, cmap = "jet")
fig.colorbar(img2, ax =axs[2])

# Axis config

fig.text(0.45, 0.05, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.05, 0.5, 'Profundidade [mm]', va='center', rotation='vertical', fontsize = 16)

# Saving and plotting
plt.savefig('POT-REAL-FluencePlots-DIV-htm-ibm14-ibm11.jpg', dpi=200)
plt.show()
