# %%
# Import libraries

import nibabel as nii
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# # Raios Teóricos

# %% [markdown]
# ### Aquisição de dados

# %%
# 0,5mm

image1_50 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R0.5-s1.nii')
image2_50 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R0.5-s2.nii')
image3_50 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R0.5-s3.nii')
image4_50 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R0.5-s4.nii')
image5_50 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R0.5-s5.nii')

data1_50 = image1_50.get_fdata()
data1_50 = np.squeeze(data1_50)
data2_50 = image2_50.get_fdata()
data2_50 = np.squeeze(data2_50)
data3_50 = image3_50.get_fdata()
data3_50 = np.squeeze(data3_50)
data4_50 = image4_50.get_fdata()
data4_50 = np.squeeze(data4_50)
data5_50 = image5_50.get_fdata()
data5_50 = np.squeeze(data5_50)

# %%
# 1,0mm

image1_100 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.0-s1.nii')
image2_100 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.0-s2.nii')
image3_100 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.0-s3.nii')
image4_100 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.0-s4.nii')
image5_100 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.0-s5.nii')

data1_100 = image1_100.get_fdata()
data1_100 = np.squeeze(data1_100)
data2_100 = image2_100.get_fdata()
data2_100 = np.squeeze(data2_100)
data3_100 = image3_100.get_fdata()
data3_100 = np.squeeze(data3_100)
data4_100 = image4_100.get_fdata()
data4_100 = np.squeeze(data4_100)
data5_100 = image5_100.get_fdata()
data5_100 = np.squeeze(data5_100)

# %%
# 2,0mm

image1_200 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.0-s1.nii')
image2_200 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.0-s2.nii')
image3_200 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.0-s3.nii')
image4_200 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.0-s4.nii')
image5_200 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.0-s5.nii')

data1_200 = image1_200.get_fdata()
data1_200 = np.squeeze(data1_200)
data2_200 = image2_200.get_fdata()
data2_200 = np.squeeze(data2_200)
data3_200 = image3_200.get_fdata()
data3_200 = np.squeeze(data3_200)
data4_200 = image4_200.get_fdata()
data4_200 = np.squeeze(data4_200)
data5_200 = image5_200.get_fdata()
data5_200 = np.squeeze(data5_200)

# %% [markdown]
# ### Suavização dos dados

# %% [markdown]
# 50 voxels = 0,5mm

# %%
# Criação da Matriz em branco
data_50_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_50_s[i][j]=(data1_50[i][j][400]+data2_50[i][j][400]+data3_50[i][j][400]+data4_50[i][j][400]+data5_50[i][j][400])/5

# %% [markdown]
# 100 voxels = 1,0mm

# %%
# Criação da Matriz em branco
data_100_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_100_s[i][j]=(data1_100[i][j][400]+data2_100[i][j][400]+data3_100[i][j][400]+data4_100[i][j][400]+data5_100[i][j][400])/5

# %% [markdown]
# 200 voxels = 2,0 mm

# %%
# Criação da Matriz em branco
data_200_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_200_s[i][j]=(data1_200[i][j][400]+data2_200[i][j][400]+data3_200[i][j][400]+data4_200[i][j][400]+data5_200[i][j][400])/5

# %% [markdown]
# ### Determinação dos valores para normalização

# %% [markdown]
# 50

# %%
maior_linha = 0
maior_coluna = 0
maior = data_50_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_50_s[l][c]:
            maior = data_50_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_50=data_50_s[maior_linha,maior_coluna]
print(max_50)
# Out:
# linha do maior: 381
# coluna do maior: 400
# 1.5762476205825806

# %% [markdown]
# 100

# %%
maior_linha = 0
maior_coluna = 0
maior = data_100_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_100_s[l][c]:
            maior = data_100_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_100=data_100_s[maior_linha,maior_coluna]
print(max_100)
# Out:
# linha do maior: 365
# coluna do maior: 405
# 0.4794486045837402

# %% [markdown]
# 200

# %%
maior_linha = 0
maior_coluna = 0
maior = data_200_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_200_s[l][c]:
            maior = data_200_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_200=data_200_s[maior_linha,maior_coluna]
print(max_200)
# Out:
# linha do maior: 351
# coluna do maior: 433
# 0.16605199873447418

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(4.0,0,400)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações - Irradiância de Entrada 1W/cm²', fontsize=20)

# Actual Lateral View Plot
# Normalization by the maximum value
# axs.plot(Y, data_50_s[:,400]/max_50, color = 'blue', label = '0.5 mm',linewidth=4.0)
# axs.plot(Y, data_100_s[:,400]/max_100, color = 'red', label = '1.0 mm',linewidth=4.0)
# axs.plot(Y, data_200_s[:,400]/max_200, color = 'green', label = '2.0 mm',linewidth=4.0)
# axs.set_ylabel('Fluência Normalizada pelo Maior Valor', fontsize=30)
# plt.legend(loc=1, prop={'size': 25})

# Normalization by the surface value
# axs.plot(Y, data_50_s[:,400]/data_50_s[399,400], color = 'blue', label = '0.5 mm',linewidth=4.0)
# axs.plot(Y, data_100_s[:,400]/data_100_s[399,400], color = 'red', label = '1.0 mm',linewidth=4.0)
# axs.plot(Y, data_200_s[:,400]/data_200_s[399,400], color = 'green', label = '2.0 mm',linewidth=4.0)
# axs.set_ylabel('Fluência Normalizada pelo Valor da Superfície', fontsize=30)
# plt.legend(loc=1, prop={'size': 25})

# Padronization using input irradiance of 1J/cm²
axs.plot(Y, data_50_s[:,400]*0.00785398, color = 'blue', label = '0.5 mm',linewidth=4.0)
axs.plot(Y, data_100_s[:,400]*0.03141592, color = 'red', label = '1.0 mm',linewidth=4.0)
axs.plot(Y, data_200_s[:,400]*0.12566370, color = 'green', label = '2.0 mm',linewidth=4.0)
axs.set_ylabel('Fluência [J/cm²]', fontsize=25)
plt.legend(loc=1, prop={'size': 25})

# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('F_decay_irradiance_1Jcm2_raios_teoricos.jpg', dpi=200)
plt.show()

# %% [markdown]
# ### Fluence Plots

# %%
# Vector to Scale Correction
X = np.linspace(-4.0,4.0,800)
Y = np.linspace(-4.0,0,400)


#Subplot
sns.set_theme()
fig,axs = plt.subplots(3,1, figsize = (12, 11))


plt.subplots_adjust(hspace = 0.5)   # Pushing up the title
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)


# Normalization by the maximum value
# axs[0].set_title('0.5 mm', fontsize=14)
# axs[0].contour(X, Y, data_50_s[:, :]/max_50, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[0].axis('equal')
# img0 = axs[0].contour(X, Y, data_50_s[:, :]/max_50, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img0, ax =axs[0])

# axs[1].set_title('1.0 mm', fontsize=14)
# axs[1].contour(X, Y, data_100_s[:, :]/max_100, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[1].axis('equal')
# img1 = axs[1].contour(X, Y, data_100_s[:, :]/max_100, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img1, ax =axs[1])

# axs[2].set_title('2.0 mm', fontsize=14)
# axs[2].contour(X, Y, data_200_s[:, :]/max_200, levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[2].axis('equal')
# img2 = axs[2].contour(X, Y, data_200_s[:, :]/max_200, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img2, ax =axs[2])
# plt.suptitle('Fluência Normalizada\n', y=0.97, x=0.425, fontsize = 20)


# Normalization by the surface value
# axs[0].set_title('0.5 mm', fontsize=14)
# axs[0].contour(X, Y, data_50_s[:, :]/data_50_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[0].axis('equal')
# img0 = axs[0].contour(X, Y, data_50_s[:, :]/data_50_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img0, ax =axs[0])

# axs[1].set_title('1.0 mm', fontsize=14)
# axs[1].contour(X, Y, data_100_s[:, :]/data_100_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[1].axis('equal')
# img1 = axs[1].contour(X, Y, data_100_s[:, :]/data_100_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img1, ax =axs[1])

# axs[2].set_title('2.0 mm', fontsize=14)
# axs[2].contour(X, Y, data_200_s[:, :]/data_200_s[399,400], levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[2].axis('equal')
# img2 = axs[2].contour(X, Y, data_200_s[:, :]/data_200_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img2, ax =axs[2])
# plt.suptitle('Fluência Normalizada\n', y=0.97, x=0.425, fontsize = 20)


# Padronization using input irradiance of 1J/cm²
axs[0].set_title('0.5 mm', fontsize=14)
axs[0].contour(X, Y, data_50_s[:, :]*0.00785398, cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
# axs[0].axis('equal')
img0 = axs[0].contour(X, Y, data_50_s[:, :]*0.00785398, cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
fig.colorbar(img0, ax =axs[0])

axs[1].set_title('1.0 mm', fontsize=14)
axs[1].contour(X, Y, data_100_s[:, :]*0.03141592, cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
# axs[1].axis('equal')
img1 = axs[1].contour(X, Y, data_100_s[:, :]*0.03141592, cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
fig.colorbar(img1, ax =axs[1])

axs[2].set_title('2.0 mm', fontsize=14)
axs[2].contour(X, Y, data_200_s[:, :]*0.12566370,cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
# axs[2].axis('equal')
img2 = axs[2].contour(X, Y, data_200_s[:, :]*0.12566370, cmap = "jet", levels = ['0.002','0.004','0.006','0.008','0.010','0.012','0.014'])
fig.colorbar(img2, ax =axs[2])
plt.suptitle('Fluência [J/cm²] \n $10^8$ fótons - 5 simulações - Irradiância de Entrada 1W/cm²', y=0.97, x=0.425, fontsize = 20)


# Axis config

fig.text(0.45, 0.05, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.07, 0.5, 'Profundidade [mm]', va='center', rotation='vertical', fontsize = 16)

# Saving and plotting
plt.savefig('F_profile_irradiance_1Jcm2_raios_teoricos.jpg', dpi=200)
plt.show()

# %% [markdown]
# # Raios Girasol

# %% [markdown]
# ### Aquisição de dados

# %%
# 1,59mm

image1_159 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.59-s1.nii')
image2_159 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.59-s2.nii')
image3_159 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.59-s3.nii')
image4_159 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.59-s4.nii')
image5_159 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R1.59-s5.nii')

data1_159 = image1_159.get_fdata()
data1_159 = np.squeeze(data1_159)
data2_159 = image2_159.get_fdata()
data2_159 = np.squeeze(data2_159)
data3_159 = image3_159.get_fdata()
data3_159 = np.squeeze(data3_159)
data4_159 = image4_159.get_fdata()
data4_159 = np.squeeze(data4_159)
data5_159 = image5_159.get_fdata()
data5_159 = np.squeeze(data5_159)

# %%
# 2,08mm

image1_208 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.08-s1.nii')
image2_208 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.08-s2.nii')
image3_208 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.08-s3.nii')
image4_208 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.08-s4.nii')
image5_208 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R2.08-s5.nii')

data1_208 = image1_208.get_fdata()
data1_208 = np.squeeze(data1_208)
data2_208 = image2_208.get_fdata()
data2_208 = np.squeeze(data2_208)
data3_208 = image3_208.get_fdata()
data3_208 = np.squeeze(data3_208)
data4_208 = image4_208.get_fdata()
data4_208 = np.squeeze(data4_208)
data5_208 = image5_208.get_fdata()
data5_208 = np.squeeze(data5_208)

# %%
# 3,46mm

image1_346 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R3.46-s1.nii')
image2_346 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R3.46-s2.nii')
image3_346 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R3.46-s3.nii')
image4_346 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R3.46-s4.nii')
image5_346 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-904-R3.46-s5.nii')

data1_346 = image1_346.get_fdata()
data1_346 = np.squeeze(data1_346)
data2_346 = image2_346.get_fdata()
data2_346 = np.squeeze(data2_346)
data3_346 = image3_346.get_fdata()
data3_346 = np.squeeze(data3_346)
data4_346 = image4_346.get_fdata()
data4_346 = np.squeeze(data4_346)
data5_346 = image5_346.get_fdata()
data5_346 = np.squeeze(data5_346)

# %% [markdown]
# ### Suavização dos dados

# %% [markdown]
# 159 voxels = 1,59mm

# %%
# Criação da Matriz em branco
data_159_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_159_s[i][j]=(data1_159[i][j][400]+data2_159[i][j][400]+data3_159[i][j][400]+data4_159[i][j][400]+data5_159[i][j][400])/5

# %% [markdown]
# 208 voxels = 2,08mm

# %%
# Criação da Matriz em branco
data_208_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_208_s[i][j]=(data1_208[i][j][400]+data2_208[i][j][400]+data3_208[i][j][400]+data4_208[i][j][400]+data5_208[i][j][400])/5

# %% [markdown]
# 346 voxels = 3,46 mm

# %%
# Criação da Matriz em branco
data_346_s = np.zeros((400,800))

# Loop de suavização do conjunto de dados
for i in range(400):
    for j in range(800):
        data_346_s[i][j]=(data1_346[i][j][400]+data2_346[i][j][400]+data3_346[i][j][400]+data4_346[i][j][400]+data5_346[i][j][400])/5

# %% [markdown]
# ### Determinação dos valores para normalização

# %% [markdown]
# 159

# %%
maior_linha = 0
maior_coluna = 0
maior = data_159_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_159_s[l][c]:
            maior = data_159_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_159=data_159_s[maior_linha,maior_coluna]
print(max_159)
# Out:
# linha do maior: 358
# coluna do maior: 397
# 0.23330751657485962

# %% [markdown]
# 208

# %%
maior_linha = 0
maior_coluna = 0
maior = data_208_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_208_s[l][c]:
            maior = data_208_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_208=data_208_s[maior_linha,maior_coluna]
print(max_208)
# Out:
# linha do maior: 362
# coluna do maior: 421
# 0.15701957941055297

# %% [markdown]
# 346

# %%
maior_linha = 0
maior_coluna = 0
maior = data_346_s[0,0]
for l in range(400):
    for c in range(800):        
        if maior < data_346_s[l][c]:
            maior = data_346_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_346=data_346_s[maior_linha,maior_coluna]
print(max_346)
# Out:
# linha do maior: 354
# coluna do maior: 400
# 0.07565362155437469

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(4.0,0,400)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações - Irradiância de Entrada 1W/cm²', fontsize=20)

# # Actual Lateral View Plot - Norm. Maximum Value
# axs.plot(Y, data_159_s[:,400]/max_159, color = 'blue', label = '1.59 mm',linewidth=4.0)
# axs.plot(Y, data_208_s[:,400]/max_208, color = 'red', label = '2.08 mm',linewidth=4.0)
# axs.plot(Y, data_346_s[:,400]/max_346, color = 'green', label = '3.46 mm',linewidth=4.0)
# plt.legend(loc=1, prop={'size': 25})
# axs.set_ylabel('Fluência Normalizada pelo Maior Valor', fontsize=30)


# # Actual Lateral View Plot - Norm. Surface Value
# axs.plot(Y, data_159_s[:,400]/data_159_s[399,400], color = 'blue', label = '1.59 mm',linewidth=4.0)
# axs.plot(Y, data_208_s[:,400]/data_208_s[399,400], color = 'red', label = '2.08 mm',linewidth=4.0)
# axs.plot(Y, data_346_s[:,400]/data_346_s[399,400], color = 'green', label = '3.46 mm',linewidth=4.0)
# plt.legend(loc=1, prop={'size': 25})
# axs.set_ylabel('Fluência Normalizada pelo Valor da Superfície', fontsize=30)


# Actual Lateral View Plot - Incident Irradiance 1J/cm²
axs.plot(Y, data_159_s[:,400]*0.07942260, color = 'blue', label = '1.59 mm',linewidth=4.0)
axs.plot(Y, data_208_s[:,400]*0.13591786, color = 'red', label = '2.08 mm',linewidth=4.0)
axs.plot(Y, data_346_s[:,400]*0.37609890, color = 'green', label = '3.46 mm',linewidth=4.0)
plt.legend(loc=1, prop={'size': 25})
axs.set_ylabel('Fluência [J/cm²]', fontsize=25)


# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# plt.savefig('F_decay_irradiance_1Jcm2_raios_reais.jpg', dpi=200)
plt.show()

# %% [markdown]
# ### Fluence Plots

# %%
# Vector to Scale Correction
X = np.linspace(-4.0,4.0,800)
Y = np.linspace(-4.0,0,400)

#Subplot
sns.set_theme()
fig,axs = plt.subplots(3,1, figsize = (12, 11))


plt.subplots_adjust(hspace = 0.5)   # Pushing up the title
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# # Normalization by maximum value
# plt.suptitle('Fluência Normalizada', y=0.92, x=0.425, fontsize = 20)
# axs[0].set_title('1.59 mm', fontsize=14)
# axs[0].contour(X, Y, data_159_s[:, :]/max_159, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[0].axis('equal')
# img0 = axs[0].contour(X, Y, data_159_s[:, :]/max_159, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img0, ax =axs[0])

# axs[1].set_title('2.08 mm', fontsize=14)
# axs[1].contour(X, Y, data_208_s[:, :]/max_208, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[1].axis('equal')
# img1 = axs[1].contour(X, Y, data_208_s[:, :]/max_208, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img1, ax =axs[1])

# axs[2].set_title('3.46 mm', fontsize=14)
# axs[2].contour(X, Y, data_346_s[:, :]/max_346, levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[2].axis('equal')
# img2 = axs[2].contour(X, Y, data_346_s[:, :]/max_346, cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img2, ax =axs[2])


# # Normalization by surface value
# plt.suptitle('Fluência Normalizada', y=0.92, x=0.425, fontsize = 20)
# axs[0].set_title('1.59 mm', fontsize=14)
# axs[0].contour(X, Y, data_159_s[:, :]/data_159_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[0].axis('equal')
# img0 = axs[0].contour(X, Y, data_159_s[:, :]/data_159_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img0, ax =axs[0])

# axs[1].set_title('2.08 mm', fontsize=14)
# axs[1].contour(X, Y, data_208_s[:, :]/data_208_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[1].axis('equal')
# img1 = axs[1].contour(X, Y, data_208_s[:, :]/data_208_s[399,400], cmap = "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img1, ax =axs[1])

# axs[2].set_title('3.46 mm', fontsize=14)
# axs[2].contour(X, Y, data_346_s[:, :]/data_346_s[399,400], levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# # axs[2].axis('equal')
# img2 = axs[2].contour(X, Y, data_346_s[:, :]/data_346_s[399,400], cmap= "jet", levels = ['0.00','0.15','0.30','0.45','0.60','0.75','0.90','1.00'])
# fig.colorbar(img2, ax =axs[2])


# Irradiance of 1W/cm²
plt.suptitle('Fluência [J/cm²] \n $10^8$ fótons - 5 simulações - Irradiância de Entrada 1W/cm²', y=0.97, x=0.425, fontsize = 20)
axs[0].set_title('1.59 mm', fontsize=14)
axs[0].contour(X, Y, data_159_s[:, :]*0.07942260, cmap = "jet", levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
# axs[0].axis('equal')
img0 = axs[0].contour(X, Y, data_159_s[:, :]*0.07942260, cmap = "jet", levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
fig.colorbar(img0, ax =axs[0])

axs[1].set_title('2.08 mm', fontsize=14)
axs[1].contour(X, Y, data_208_s[:, :]*0.13591786, cmap = "jet", levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
# axs[1].axis('equal')
img1 = axs[1].contour(X, Y, data_208_s[:, :]*0.13591786, cmap = "jet", levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
fig.colorbar(img1, ax =axs[1])

axs[2].set_title('3.46 mm', fontsize=14)
axs[2].contour(X, Y, data_346_s[:, :]*0.37609890, cmap='jet', levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
# axs[2].axis('equal')
img2 = axs[2].contour(X, Y, data_346_s[:, :]*0.37609890, cmap= "jet", levels = ['0.0025','0.0050','0.0075','0.0100','0.0125','0.0150','0.0175','0.0200'])
fig.colorbar(img2, ax =axs[2])
# Axis config

fig.text(0.45, 0.05, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.07, 0.5, 'Profundidade [mm]', va='center', rotation='vertical', fontsize = 16)

# Saving and plotting
# plt.savefig('F_profile_irradiance_1Jcm2_raios_reais.jpg', dpi=200)
plt.show()

# %% [markdown]
# # Raios Artigo Girasol

# %% [markdown]
# Importação de Dados

# %%
# r1

image1_r1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r1-s1.nii')
image2_r1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r1-s2.nii')
image3_r1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r1-s3.nii')
image4_r1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r1-s4.nii')
image5_r1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r1-s5.nii')

data1_r1 = image1_r1.get_fdata()
data1_r1 = np.squeeze(data1_r1)

data2_r1 = image2_r1.get_fdata()
data2_r1 = np.squeeze(data2_r1)

data3_r1 = image3_r1.get_fdata()
data3_r1 = np.squeeze(data3_r1)

data4_r1 = image4_r1.get_fdata()
data4_r1 = np.squeeze(data4_r1)

data5_r1 = image5_r1.get_fdata()
data5_r1 = np.squeeze(data5_r1)

# r2

image1_r2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r2-s1.nii')
image2_r2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r2-s2.nii')
image3_r2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r2-s3.nii')
image4_r2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r2-s4.nii')
image5_r2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r2-s5.nii')

data1_r2 = image1_r2.get_fdata()
data1_r2 = np.squeeze(data1_r2)

data2_r2 = image2_r2.get_fdata()
data2_r2 = np.squeeze(data2_r2)

data3_r2 = image3_r2.get_fdata()
data3_r2 = np.squeeze(data3_r2)

data4_r2 = image4_r2.get_fdata()
data4_r2 = np.squeeze(data4_r2)

data5_r2 = image5_r2.get_fdata()
data5_r2 = np.squeeze(data5_r2)

# r3

image1_r3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r3-s1.nii')
image2_r3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r3-s2.nii')
image3_r3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r3-s3.nii')
image4_r3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r3-s4.nii')
image5_r3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r3-s5.nii')

data1_r3 = image1_r3.get_fdata()
data1_r3 = np.squeeze(data1_r3)

data2_r3 = image2_r3.get_fdata()
data2_r3 = np.squeeze(data2_r3)

data3_r3 = image3_r3.get_fdata()
data3_r3 = np.squeeze(data3_r3)

data4_r3 = image4_r3.get_fdata()
data4_r3 = np.squeeze(data4_r3)

data5_r3 = image5_r3.get_fdata()
data5_r3 = np.squeeze(data5_r3)

# r4

image1_r4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r4-s1.nii')
image2_r4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r4-s2.nii')
image3_r4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r4-s3.nii')
image4_r4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r4-s4.nii')
image5_r4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r4-s5.nii')

data1_r4 = image1_r4.get_fdata()
data1_r4 = np.squeeze(data1_r4)

data2_r4 = image2_r4.get_fdata()
data2_r4 = np.squeeze(data2_r4)

data3_r4 = image3_r4.get_fdata()
data3_r4 = np.squeeze(data3_r4)

data4_r4 = image4_r4.get_fdata()
data4_r4 = np.squeeze(data4_r4)

data5_r4 = image5_r4.get_fdata()
data5_r4 = np.squeeze(data5_r4)

# r5

image1_r5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r5-s1.nii')
image2_r5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r5-s2.nii')
image3_r5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r5-s3.nii')
image4_r5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r5-s4.nii')
image5_r5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-r5-s5.nii')

data1_r5 = image1_r5.get_fdata()
data1_r5 = np.squeeze(data1_r5)

data2_r5 = image2_r5.get_fdata()
data2_r5 = np.squeeze(data2_r5)

data3_r5 = image3_r5.get_fdata()
data3_r5 = np.squeeze(data3_r5)

data4_r5 = image4_r5.get_fdata()
data4_r5 = np.squeeze(data4_r5)

data5_r5 = image5_r5.get_fdata()
data5_r5 = np.squeeze(data5_r5)

# %% [markdown]
# Correção de Dados

# %%
# Correction r1

data1_r1 = data1_r1*0.0260755
data2_r1 = data2_r1*0.0260755
data3_r1 = data3_r1*0.0260755
data4_r1 = data4_r1*0.0260755
data5_r1 = data5_r1*0.0260755

# Correction r2

data1_r2 = data1_r2*0.0624580
data2_r2 = data2_r2*0.0624580
data3_r2 = data3_r2*0.0624580
data4_r2 = data4_r2*0.0624580
data5_r2 = data5_r2*0.0624580

# Correction r3

data1_r3 = data1_r3*0.1359178
data2_r3 = data2_r3*0.1359178
data3_r3 = data3_r3*0.1359178
data4_r3 = data4_r3*0.1359178
data5_r3 = data5_r3*0.1359178

# Correction r4

data1_r4 = data1_r4*0.2273287
data2_r4 = data2_r4*0.2273287
data3_r4 = data3_r4*0.2273287
data4_r4 = data4_r4*0.2273287
data5_r4 = data5_r4*0.2273287

# Correction r5

data1_r5 = data1_r5*0.3760989
data2_r5 = data2_r5*0.3760989
data3_r5 = data3_r5*0.3760989
data4_r5 = data4_r5*0.3760989
data5_r5 = data5_r5*0.3760989

# %% [markdown]
# Suavização de Dados

# %%
#r1

# Criação da Matriz em branco
data_r1_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_r1_s[i][j]=(data1_r1[i][j][50]+data2_r1[i][j][50]+data3_r1[i][j][50]+data4_r1[i][j][50]+data5_r1[i][j][50])/5
        
#r2

# Criação da Matriz em branco
data_r2_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_r2_s[i][j]=(data1_r2[i][j][50]+data2_r2[i][j][50]+data3_r2[i][j][50]+data4_r2[i][j][50]+data5_r2[i][j][50])/5
        
        
#r3

# Criação da Matriz em branco
data_r3_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_r3_s[i][j]=(data1_r3[i][j][50]+data2_r3[i][j][50]+data3_r3[i][j][50]+data4_r3[i][j][50]+data5_r3[i][j][50])/5
        
#r1

# Criação da Matriz em branco
data_r4_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_r4_s[i][j]=(data1_r4[i][j][50]+data2_r4[i][j][50]+data3_r4[i][j][50]+data4_r4[i][j][50]+data5_r4[i][j][50])/5
        
#r1

# Criação da Matriz em branco
data_r5_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_r5_s[i][j]=(data1_r5[i][j][50]+data2_r5[i][j][50]+data3_r5[i][j][50]+data4_r5[i][j][50]+data5_r5[i][j][50])/5

# %% [markdown]
# ### Decaimento

# %%
Y = np.linspace(4,0,40)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações - 904 nm - Entrada 1 J/cm²', fontsize=20)


# Actual Lateral View Plot
# Normalization by the maximum value
axs.plot(Y, data_r1_s[10:50,50]*0.0260155, color = "blue", label = '0.91 $\pm$ 0.20 mm',linewidth=4.0)
axs.plot(Y, data_r2_s[10:50,50]*0.0624580, color = "deepskyblue", label = '1.41 $\pm$ 0.54 mm',linewidth=4.0)
axs.plot(Y, data_r3_s[10:50,50]*0.1359178, color = "green", label = '2.08 $\pm$ 0.02 mm',linewidth=4.0)
axs.plot(Y, data_r4_s[10:50,50]*0.2273287, color = "darkorange", label = '2.69 $\pm$ 0.08 mm',linewidth=4.0)
axs.plot(Y, data_r5_s[10:50,50]*0.3760989, color = "red", label = '3.46 $\pm$ 0.38 mm',linewidth=4.0)

axs.set_ylabel('Fluência [J/cm²]', fontsize=25)
plt.legend(loc=1, prop={'size': 25})



# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# plt.savefig('1D grafico3-decaimento-raios.jpg', dpi=200)
plt.show()

# %% [markdown]
# Suavização Transversal

# %%
#0.011

# Criação da Matriz em branco
data_r1_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_r1_s_t[i][j]=(data1_r1[34][i][j]+data2_r1[34][i][j]+data3_r1[34][i][j]+data4_r1[34][i][j]+data5_r1[34][i][j])/5
        
#0.015

# Criação da Matriz em branco
data_r2_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_r2_s_t[i][j]=(data1_r2[34][i][j]+data2_r2[34][i][j]+data3_r2[34][i][j]+data4_r2[34][i][j]+data5_r2[34][i][j])/5
        
#0.020

# Criação da Matriz em branco
data_r3_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_r3_s_t[i][j]=(data1_r3[34][i][j]+data2_r3[34][i][j]+data3_r3[34][i][j]+data4_r3[34][i][j]+data5_r3[34][i][j])/5
        
#0.027

# Criação da Matriz em branco
data_r4_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_r4_s_t[i][j]=(data1_r4[34][i][j]+data2_r4[34][i][j]+data3_r4[34][i][j]+data4_r4[34][i][j]+data5_r4[34][i][j])/5
        
#0.020

# Criação da Matriz em branco
data_r5_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_r5_s_t[i][j]=(data1_r5[34][i][j]+data2_r5[34][i][j]+data3_r5[34][i][j]+data4_r5[34][i][j]+data5_r5[34][i][j])/5

# %% [markdown]
# ## 2D fluência

# %%
#Subplot

X = np.linspace(-5,5,100)
Y = np.linspace(-5,0,50)
X2 = np.linspace(-5,5,100)
Y2 = np.linspace(-5,5,100)

sns.set_theme()
fig,axs = plt.subplots(2,3, figsize = (20, 10))
plt.suptitle('Distribuição de Fluência [mJ/cm²] \n Densidade de fluência de entrada 1J/cm²\n', y=0.975, x=0.49, fontsize = 20)

plt.subplots_adjust(hspace = 0.25)   # Pushing up the title
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

axs[0][0].set_title('0.91 mm - Visão Lateral', fontsize=16)
axs[0][0].contour(X, Y, 1000*data_r1_s[:, :], cmap = "jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)
axs[0][0].axis('equal')
img0 = axs[0][0].contour(X, Y, 1000*data_r1_s[:, :], cmap = "jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)  # Creates an object with the plot
fig.colorbar(img0, ax =axs[0][0])

axs[0][1].set_title('2.08 mm - Visão Lateral', fontsize=16)
axs[0][1].contour(X, Y, 1000*data_r3_s[:, :], cmap="jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)
axs[0][1].axis('equal')
img1 = axs[0][1].contour(X, Y,1000*data_r3_s[:, :], cmap="jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)
fig.colorbar(img1, ax =axs[0][1])

axs[0][2].set_title('3.46 mm - Visão Lateral', fontsize=16)
axs[0][2].contour(X, Y, 1000*data_r5_s[:, :],cmap="jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)
axs[0][2].axis('equal')
img2 = axs[0][2].contour(X, Y, 1000*data_r5_s[:, :], cmap = "jet",levels = ['0','2','4','6','8','10','12','14','16'],linewidths=3.0)
fig.colorbar(img2, ax =axs[0][2])


axs[1][0].set_title('0.91 mm - Seção Transversal', fontsize=16)
axs[1][0].contour(X2, Y2, 1000*data_r1_s_t[:, :], cmap = "jet",levels = ['1.9','3','4','5','6','7','8'], linewidths=3.0)
axs[1][0].axis('equal')
img0 = axs[1][0].contour(X2, Y2, 1000*data_r1_s_t[:, :], cmap = "jet",levels = ['1.9','3','4','5','6','7','8'],linewidths=3.0)  # Creates an object with the plot
fig.colorbar(img0, ax =axs[1][0])

axs[1][1].set_title('2.08 mm - Seção Transversal', fontsize=16)
axs[1][1].contour(X2, Y2, 1000*data_r3_s_t[:, :], cmap = "jet",levels = ['2.3','3','4','5','6','7','8'],linewidths=3.0)
axs[1][1].axis('equal')
img1 = axs[1][1].contour(X2, Y2, 1000*data_r3_s_t[:, :], cmap = "jet",levels = ['2.3','3','4','5','6','7','8'], linewidths=3.0)
fig.colorbar(img1, ax =axs[1][1])

axs[1][2].set_title('3.46 mm - Seção Transversal', fontsize=16)
axs[1][2].contour(X2, Y2,1000*data_r5_s_t[:, :], cmap = "jet",levels = ['2.7','3','4','5','6','7','8'],linewidths=3.0)
axs[1][2].axis('equal')
img2 = axs[1][2].contour(X2, Y2, 1000*data_r5_s_t[:, :], cmap = "jet",levels = ['2.7','3','4','5','6','7','8'], linewidths=3.0)
fig.colorbar(img2, ax =axs[1][2])

# Axis config

fig.text(0.5, 0.06, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.09, 0.5, 'Comprimento [mm]                           Profundidade [mm]', va='center', rotation='vertical', fontsize = 18)

# Saving and plotting
plt.savefig('2D grafico2-perfil-fluencia-raios.jpg')
plt.show()
