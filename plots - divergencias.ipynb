# %%
# Import libraries

import nibabel as nii
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# # Divergências Teóricas

# %% [markdown]
# ### Aquisição dos Dados

# %%
# 15

image1_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s1.nii')
image2_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s2.nii')
image3_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s3.nii')
image4_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s4.nii')
image5_15 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-15graus-s5.nii')

data1_15 = image1_15.get_fdata()
data1_15 = np.squeeze(data1_15)
data2_15 = image2_15.get_fdata()
data2_15 = np.squeeze(data2_15)
data3_15 = image3_15.get_fdata()
data3_15 = np.squeeze(data3_15)
data4_15 = image4_15.get_fdata()
data4_15 = np.squeeze(data4_15)
data5_15 = image5_15.get_fdata()
data5_15 = np.squeeze(data5_15)

# %%
# 60


image1_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s1.nii')
image2_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s2.nii')
image3_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s3.nii')
image4_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s4.nii')
image5_60 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-60graus-s5.nii')

data1_60 = image1_60.get_fdata()
data1_60 = np.squeeze(data1_60)
data2_60 = image2_60.get_fdata()
data2_60 = np.squeeze(data2_60)
data3_60 = image3_60.get_fdata()
data3_60 = np.squeeze(data3_60)
data4_60 = image4_60.get_fdata()
data4_60 = np.squeeze(data4_60)
data5_60 = image5_60.get_fdata()
data5_60 = np.squeeze(data5_60)

# %%
# # 120

image1_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s1.nii')
image2_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s2.nii')
image3_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s3.nii')
image4_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s4.nii')
image5_120 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\FR-904-120graus-s5.nii')

data1_120 = image1_120.get_fdata()
data1_120 = np.squeeze(data1_120)
data2_120 = image2_120.get_fdata()
data2_120 = np.squeeze(data2_120)
data3_120 = image3_120.get_fdata()
data3_120 = np.squeeze(data3_120)
data4_120 = image4_120.get_fdata()
data4_120 = np.squeeze(data4_120)
data5_120 = image5_120.get_fdata()
data5_120 = np.squeeze(data5_120)

# print(np.size(data1_120))

# %% [markdown]
# ### Suavização dos Dados

# %% [markdown]
# 15 graus

# %%
# Criação da Matriz em branco
data_15_s = np.zeros((100,600))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(600):
        data_15_s[i][j]=(data1_15[i][j][300]+data2_15[i][j][300]+data3_15[i][j][300]+data4_15[i][j][300]+data5_15[i][j][300])/5

# %% [markdown]
# 60 graus

# %%
# Criação da Matriz em branco
data_60_s = np.zeros((100,600))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(600):
        data_60_s[i][j]=(data1_60[i][j][300]+data2_60[i][j][300]+data3_60[i][j][300]+data4_60[i][j][300]+data5_60[i][j][300])/5

# %% [markdown]
# 120 graus

# %%
# Criação da Matriz em branco
data_120_s = np.zeros((100,600))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(600):
        data_120_s[i][j]=(data1_120[i][j][300]+data2_120[i][j][300]+data3_120[i][j][300]+data4_120[i][j][300]+data5_120[i][j][300])/5

# %% [markdown]
# ### Determinação dos valores para normalização

# %% [markdown]
# 15

# %%
maior_linha = 0
maior_coluna = 0
maior = data_15_s[0,0]
for l in range(100):
    for c in range(600):        
        if maior < data_15_s[l][c]:
            maior = data_15_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_15=data_15_s[maior_linha,maior_coluna]
print(max_15)
# Out:
# linha do maior: 99
# coluna do maior: 300
# 2553.289208984375

# %% [markdown]
# 60

# %%
maior_linha = 0
maior_coluna = 0
maior = data_60_s[0,0]
for l in range(100):
    for c in range(600):        
        if maior < data_60_s[l][c]:
            maior = data_60_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_60=data_60_s[maior_linha,maior_coluna]
print(max_60)
# Out:
# linha do maior: 99
# coluna do maior: 299
# 3173.4876953125

# %% [markdown]
# 120

# %%
maior_linha = 0
maior_coluna = 0
maior = data_120_s[0,0]
for l in range(100):
    for c in range(600):        
        if maior < data_120_s[l][c]:
            maior = data_120_s[l][c]
            maior_linha = l
            maior_coluna = c

print('linha do maior: {}\ncoluna do maior: {}'.format(maior_linha, maior_coluna))
max_120=data_120_s[maior_linha,maior_coluna]
print(max_120)
# Out:
# linha do maior: 99
# coluna do maior: 300
# 3059.252392578125

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(0.3,0,30)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title


# # Actual Lateral View Plot - Norm. by maximum value
# axs.plot(Y, data_15_s[70:100,300]/max_15, color = 'blue', label = '15°',linewidth=4.0)
# axs.plot(Y, data_60_s[70:100,300]/max_60, color = 'red', label = '60°',linewidth=4.0)
# axs.plot(Y, data_120_s[70:100,300]/max_120, color = 'green', label = '120°',linewidth=4.0)
# plt.legend(loc=1, prop={'size': 25})
# axs.set_ylabel('Fluência Normalizada', fontsize=30)
# axs.set_title('$10^8$ fótons - 5 simulações', fontsize=20)


# # Norm. by surface value
axs.plot(Y, data_15_s[70:100,300]/data_15_s[99,300], color = 'blue', label = '15°',linewidth=4.0)
axs.plot(Y, data_60_s[70:100,300]/data_60_s[99,300], color = 'red', label = '60°',linewidth=4.0)
axs.plot(Y, data_120_s[70:100,300]/data_15_s[99,300], color = 'green', label = '120°',linewidth=4.0)
plt.legend(loc=1, prop={'size': 25})
axs.set_ylabel('Fluência Normalizada', fontsize=25)
axs.set_title('$10^8$ fótons - 5 simulações', fontsize=20)


# # Irradiance 1J/cm²
# axs.plot(Y, data_15_s[70:100,300]*0.0000031415, color = 'blue', label = '15°',linewidth=4.0)
# axs.plot(Y, data_60_s[70:100,300]*0.0000031415, color = 'red', label = '60°',linewidth=4.0)
# axs.plot(Y, data_120_s[70:100,300]*0.0000031415, color = 'green', label = '120°',linewidth=4.0)
# plt.legend(loc=1, prop={'size': 25})
# axs.set_ylabel('Fluência [J/cm²]', fontsize=30)
# axs.set_title('$10^8$ fótons - 5 simulações - Irradiância 1W/cm²', fontsize=20)

# Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('F_decay_irradiance_norm_sup_divergencias_teoricas.jpg', dpi=200)
plt.show()

# %% [markdown]
# ### Fluence Plots

# %%
# Vector to Scale Correction
X = np.linspace(-0.25,0.25,50)
Y = np.linspace(-0.15,0,15)

#Subplot
sns.set_theme()
fig,axs = plt.subplots(3,1, figsize = (12, 11))
plt.suptitle('Fluência Normalizada',y=0.95, x=0.425, fontsize = 20)

plt.subplots_adjust(hspace = 0.5)   # Pushing up the title
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

axs[0].set_title('15°', fontsize=14)
axs[0].contour(X, Y, data_15_s[85:100, 275:325]/data_15_s[99,300], cmap = "jet")
# axs[0].axis('equal')
img0 = axs[0].contour(X, Y, data_15_s[85:100, 275:325]/data_15_s[99,300], cmap = "jet")
fig.colorbar(img0, ax =axs[0])

axs[1].set_title('60°', fontsize=14)
axs[1].contour(X, Y, data_60_s[85:100, 275:325]/data_60_s[99,300], cmap = "jet")
# axs[1].axis('equal')
img1 = axs[1].contour(X, Y, data_60_s[85:100, 275:325]/data_60_s[99,300], cmap = "jet")
fig.colorbar(img1, ax =axs[1])

axs[2].set_title('120°', fontsize=14)
axs[2].contour(X, Y, data_120_s[85:100, 275:325]/data_120_s[99,300], cmap = "jet")
# axs[2].axis('equal')
img2 = axs[2].contour(X, Y, data_120_s[85:100, 275:325]/data_120_s[99,300], cmap = "jet")
fig.colorbar(img2, ax =axs[2])

# Axis config

fig.text(0.45, 0.08, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.05, 0.5, 'Profundidade [mm]', va='center', rotation='vertical', fontsize = 16)

# Saving and plotting
plt.savefig('F_profile_irradiance_norm_sup_divergencias_teoricas.jpg', dpi=200)
plt.show()

# %% [markdown]
# # Divergências Girasol

# %% [markdown]
# ### Aquisição de Dados

# %%
# 0.011

image1_t1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta1-s1.nii')
image2_t1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta1-s2.nii')
image3_t1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta1-s3.nii')
image4_t1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta1-s4.nii')
image5_t1 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta1-s5.nii')

data1_t1 = image1_t1.get_fdata()
data1_t1 = np.squeeze(data1_t1)

data2_t1 = image2_t1.get_fdata()
data2_t1 = np.squeeze(data2_t1)

data3_t1 = image3_t1.get_fdata()
data3_t1 = np.squeeze(data3_t1)

data4_t1 = image4_t1.get_fdata()
data4_t1 = np.squeeze(data4_t1)

data5_t1 = image5_t1.get_fdata()
data5_t1 = np.squeeze(data5_t1)

# %%
# 0.015

image1_t2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta2-s1.nii')
image2_t2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta2-s2.nii')
image3_t2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta2-s3.nii')
image4_t2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta2-s4.nii')
image5_t2 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta2-s5.nii')

data1_t2 = image1_t2.get_fdata()
data1_t2 = np.squeeze(data1_t2)

data2_t2 = image2_t2.get_fdata()
data2_t2 = np.squeeze(data2_t2)

data3_t2 = image3_t2.get_fdata()
data3_t2 = np.squeeze(data3_t2)

data4_t2 = image4_t2.get_fdata()
data4_t2 = np.squeeze(data4_t2)

data5_t2 = image5_t2.get_fdata()
data5_t2 = np.squeeze(data5_t2)

# %%
# 0.020 (teorico)

image1_t3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta3-s1.nii')
image2_t3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta3-s2.nii')
image3_t3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta3-s3.nii')
image4_t3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta3-s4.nii')
image5_t3 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta3-s5.nii')

data1_t3 = image1_t3.get_fdata()
data1_t3 = np.squeeze(data1_t3)

data2_t3 = image2_t3.get_fdata()
data2_t3 = np.squeeze(data2_t3)

data3_t3 = image3_t3.get_fdata()
data3_t3 = np.squeeze(data3_t3)

data4_t3 = image4_t3.get_fdata()
data4_t3 = np.squeeze(data4_t3)

data5_t3 = image5_t3.get_fdata()
data5_t3 = np.squeeze(data5_t3)

# %%
# 0.027

image1_t4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta4-s1.nii')
image2_t4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta4-s2.nii')
image3_t4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta4-s3.nii')
image4_t4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta4-s4.nii')
image5_t4 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta4-s5.nii')

data1_t4 = image1_t4.get_fdata()
data1_t4 = np.squeeze(data1_t4)

data2_t4 = image2_t4.get_fdata()
data2_t4 = np.squeeze(data2_t4)

data3_t4 = image3_t4.get_fdata()
data3_t4 = np.squeeze(data3_t4)

data4_t4 = image4_t4.get_fdata()
data4_t4 = np.squeeze(data4_t4)

data5_t4 = image5_t4.get_fdata()
data5_t4 = np.squeeze(data5_t4)

# %%
# 0.034

image1_t5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta5-s1.nii')
image2_t5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta5-s2.nii')
image3_t5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta5-s3.nii')
image4_t5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta5-s4.nii')
image5_t5 = nii.load(r'C:\Users\User\Documents\Raíssa\Curso Monte Carlo\pymcx-master\pymcx\F-div-theta5-s5.nii')

data1_t5 = image1_t5.get_fdata()
data1_t5 = np.squeeze(data1_t5)

data2_t5 = image2_t5.get_fdata()
data2_t5 = np.squeeze(data2_t5)

data3_t5 = image3_t5.get_fdata()
data3_t5 = np.squeeze(data3_t5)

data4_t5 = image4_t5.get_fdata()
data4_t5 = np.squeeze(data4_t5)

data5_t5 = image5_t5.get_fdata()
data5_t5 = np.squeeze(data5_t5)

# %% [markdown]
# ### Suavização de Dados

# %%
#0.011

# Criação da Matriz em branco
data_t1_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_t1_s[i][j]=(data1_t1[i][j][50]+data2_t1[i][j][50]+data3_t1[i][j][50]+data4_t1[i][j][50]+data5_t1[i][j][50])/5

# %%
#0.015

# Criação da Matriz em branco
data_t2_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_t2_s[i][j]=(data1_t2[i][j][50]+data2_t2[i][j][50]+data3_t2[i][j][50]+data4_t2[i][j][50]+data5_t2[i][j][50])/5

# %%
#0.020

# Criação da Matriz em branco
data_t3_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_t3_s[i][j]=(data1_t3[i][j][50]+data2_t3[i][j][50]+data3_t3[i][j][50]+data4_t3[i][j][50]+data5_t3[i][j][50])/5

# %%
#0.027

# Criação da Matriz em branco
data_t4_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_t4_s[i][j]=(data1_t4[i][j][50]+data2_t4[i][j][50]+data3_t4[i][j][50]+data4_t4[i][j][50]+data5_t4[i][j][50])/5

# %%
#0.034

# Criação da Matriz em branco
data_t5_s = np.zeros((50,100))

# Loop de suavização do conjunto de dados
for i in range(50):
    for j in range(100):
        data_t5_s[i][j]=(data1_t5[i][j][50]+data2_t5[i][j][50]+data3_t5[i][j][50]+data4_t5[i][j][50]+data5_t5[i][j][50])/5

# %% [markdown]
# ### Decaimento em Profundidade

# %%
Y = np.linspace(2,0,20)

sns.set_theme()
fig,axs = plt.subplots(1, figsize = (20, 14))
plt.suptitle('Decaimento em Profundidade da Fluência', y=0.94, x=0.51, fontsize=30)
plt.subplots_adjust(hspace = 0.7)   # Pushing up the title
axs.set_title('$10^8$ fótons - 5 simulações - 904 nm - Entrada 1 J/cm²', fontsize=20)


# Actual Lateral View Plot
# Normalization by the maximum value
axs.plot(Y, data_t1_s[30:50,50]*0.090792, color = "blue", label = '0.011 $\pm$ 0.001 rad',linewidth=4.0)
axs.plot(Y, data_t2_s[30:50,50]*0.090792, color = "deepskyblue", label = '0.015 $\pm$ 0.001 rad',linewidth=4.0)
axs.plot(Y, data_t3_s[30:50,50]*0.090792, color = "green", label = '0.020 rad (teórico)',linewidth=4.0)
axs.plot(Y, data_t4_s[30:50,50]*0.090792, color = "darkorange", label = '0.027 $\pm$ 0.000 rad',linewidth=4.0)
axs.plot(Y, data_t5_s[30:50,50]*0.090792, color = "red", label = '0.034 $\pm$ 0.008 rad',linewidth=4.0)

axs.set_ylabel('Fluência [J/cm²]', fontsize=25)
plt.legend(loc=1, prop={'size': 25})



# # Legend for the axis
axs.set_xlabel('Profundidade [mm]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('1D grafico3-decaimento-divergencias.jpg', dpi=200)
plt.show()

# %% [markdown]
# ### Suavização - Corte transversal

# %%
#0.011

# Criação da Matriz em branco
data_t1_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_t1_s_t[i][j]=(data1_t1[34][i][j]+data2_t1[34][i][j]+data3_t1[34][i][j]+data4_t1[34][i][j]+data5_t1[34][i][j])/5

# %%
#0.015

# Criação da Matriz em branco
data_t2_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_t2_s_t[i][j]=(data1_t2[34][i][j]+data2_t2[34][i][j]+data3_t2[34][i][j]+data4_t2[34][i][j]+data5_t2[34][i][j])/5

# %%
#0.020

# Criação da Matriz em branco
data_t3_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_t3_s_t[i][j]=(data1_t3[34][i][j]+data2_t3[34][i][j]+data3_t3[34][i][j]+data4_t3[34][i][j]+data5_t3[34][i][j])/5

# %%
#0.027

# Criação da Matriz em branco
data_t4_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_t4_s_t[i][j]=(data1_t4[34][i][j]+data2_t4[34][i][j]+data3_t4[34][i][j]+data4_t4[34][i][j]+data5_t4[34][i][j])/5

# %%
#0.020

# Criação da Matriz em branco
data_t5_s_t = np.zeros((100,100))

# Loop de suavização do conjunto de dados
for i in range(100):
    for j in range(100):
        data_t5_s_t[i][j]=(data1_t5[34][i][j]+data2_t5[34][i][j]+data3_t5[34][i][j]+data4_t5[34][i][j]+data5_t5[34][i][j])/5

# %% [markdown]
# ### Fluence Plots

# %%
#Subplot

X = np.linspace(-5,5,100)
Y = np.linspace(-5,0,50)
X2 = np.linspace(-5,5,100)
Y2 = np.linspace(-5,5,100)

sns.set_theme()
fig,axs = plt.subplots(2,3, figsize = (20, 10))
plt.suptitle('Distribuição de Fluência [mJ/cm²] \n Densidade de fluência de entrada 1J/cm²\n', y=0.975, x=0.49, fontsize = 20)

plt.subplots_adjust(hspace = 0.25)   # Pushing up the title
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

axs[0][0].set_title('0.011 rad - Visão Lateral', fontsize=16)
axs[0][0].contour(X, Y, 1000*data_t1_s[:, :]*0.090792, cmap = "jet", levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)
axs[0][0].axis('equal')
img0 = axs[0][0].contour(X, Y, 1000*data_t1_s[:, :]*0.090792, cmap = "jet",levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)  # Creates an object with the plot
fig.colorbar(img0, ax =axs[0][0])

axs[0][1].set_title('0.020 rad - Visão Lateral', fontsize=16)
axs[0][1].contour(X, Y, 1000*data_t3_s[:, :]*0.090792, cmap="jet",levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)
axs[0][1].axis('equal')
img1 = axs[0][1].contour(X, Y, 1000*data_t3_s[:, :]*0.090792, cmap="jet",levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)
fig.colorbar(img1, ax =axs[0][1])

axs[0][2].set_title('0.034 rad - Visão Lateral', fontsize=16)
axs[0][2].contour(X, Y, 1000*data_t5_s[:, :]*0.090792,cmap="jet",levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)
axs[0][2].axis('equal')
img2 = axs[0][2].contour(X, Y, 1000*data_t5_s[:, :]*0.090792, cmap = "jet",levels = ['2.45','5','7.5','10','12.5','15','17.5'],linewidths=3.0)
fig.colorbar(img2, ax =axs[0][2])


axs[1][0].set_title('0.011 rad - Seção Transversal', fontsize=16)
axs[1][0].contour(X2, Y2, 1000*data_t1_s_t[:, :]*0.090792, cmap = "jet",levels =['2.44','4','5','6','7','8','9','10'], linewidths=3.0)
axs[1][0].axis('equal')
img0 = axs[1][0].contour(X2, Y2, 1000*data_t1_s_t[:, :]*0.090792, cmap = "jet",levels =['2.44','4','5','6','7','8','9','10'],linewidths=3.0)  # Creates an object with the plot
fig.colorbar(img0, ax =axs[1][0])

axs[1][1].set_title('0.020 rad - Seção Transversal', fontsize=16)
axs[1][1].contour(X2, Y2, 1000*data_t3_s_t[:, :]*0.090792, cmap = "jet",levels =['2.44','4','5','6','7','8','9','10'],linewidths=3.0)
axs[1][1].axis('equal')
img1 = axs[1][1].contour(X2, Y2, 1000*data_t3_s_t[:, :]*0.090792, cmap = "jet",levels =['2.44','4','5','6','7','8','9','10'], linewidths=3.0)
fig.colorbar(img1, ax =axs[1][1])

axs[1][2].set_title('0.034 rad - Seção Transversal', fontsize=16)
axs[1][2].contour(X2, Y2,1000*data_t5_s_t[:, :]*0.090792, cmap = "jet",levels =['2.45','4','5','6','7','8','9','10'],linewidths=3.0)
axs[1][2].axis('equal')
img2 = axs[1][2].contour(X2, Y2, 1000*data_t5_s_t[:, :]*0.090792, cmap = "jet",levels =['2.45','4','5','6','7','8','9','10'], linewidths=3.0)
fig.colorbar(img2, ax =axs[1][2])

# Axis config

fig.text(0.5, 0.06, 'Largura [mm]', ha='center', fontsize = 16)
fig.text(0.09, 0.5, 'Comprimento [mm]                           Profundidade [mm]', va='center', rotation='vertical', fontsize = 18)

# Saving and plotting
plt.savefig('2D grafico2-perfil-fluencia-divergencias.jpg')
plt.show()
